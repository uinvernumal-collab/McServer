# %%
# !sudo apt update
# !sudo apt install openjdk-21-jdk -y

# %%
# !curl ifconfig.me

# %%
# !sed -i 's/eula=false/eula=true/' eula.txt
# !sed -i 's/view-distance=.*/view-distance=32/' server.properties
# !sed -i 's/simulation-distance=.*/simulation-distance=32/' server.properties
# !sed -i 's/online-mode=true/online-mode=false/' server.properties

# %%
# !chmod +x playit-linux-amd64
# !java -Xms4G -Xmx10G -XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:InitiatingHeapOccupancyPercent=15 -jar server.jar nogui & playit-linux-amd64 -s

#java -Xms6G -Xmx8G  -jar server.jar nogui
# Out:
# /bin/bash: line 1: playit-linux-amd64: command not found
# [0.000s][warning][os,container] Cgroup memory controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# [0.000s][warning][os,container] Cgroup cpu controller path at '/sys/fs/cgroup' seems to have moved to '/../../jupyter-children', detected limits won't be accurate
# Starting org.bukkit.craftbukkit.Main
# 2026-02-25T15:43:25.185547073Z ServerMain WARN Advanced terminal features are not available in this environment
# [15:43:25 INFO]: [bootstrap] Running Java 21 (OpenJDK 64-Bit Server VM 21.0.10+7-Ubuntu-122.04; Ubuntu null) on Linux 6.6.113+ (amd64)
# [15:43:25 INFO]: [bootstrap] Loading Paper 1.21.11-115-main@e17a767 (2026-02-15T01:36:16Z) for Minecraft 1.21.11
# [15:43:25 INFO]: [PluginInitializerManager] Initializing plugins...
# [15:43:26 INFO]: [PluginInitializerManager] Initialized 9 plugins
# [15:43:26 INFO]: [PluginInitializerManager] Paper plugins (2):
# ...

# %%
# !wget -nc https://fill-data.papermc.io/v1/objects/4b323b4a0273e8501784e72f09b9c10c48741fa33dcc26cf83db6f02366078e6/paper-1.21.11-115.jar -O server.jar

# %%
# !rm -rf server.jar

# %%
# !nano plugins/Geyser-Spigot/config.yml
# Out:
# >Received SIGHUP or SIGTERM

# %%
# !apt install nano

# %%
from google.colab import drive
drive.mount('/content/drive')

# !mkdir /content/drive/MyDrive/minecraft
# %cd /content/drive/MyDrive/minecraft

# !wget -nc https://fill-data.papermc.io/v1/objects/187989fbf71905b1fead292e5ff822fa6db90d0041092d3b85738648cad04ac5/paper-1.21.11-110.jar -O server.jar

# !java -Xms2G -Xmx4G -jar server.jar nogui


# !sed -i 's/eula=false/eula=true/' eula.txt
# !sed -i 's/view-distance=.*/view-distance=8/' server.properties
# !sed -i 's/simulation-distance=.*/simulation-distance=8/' server.properties
# !sed -i 's/online-mode=true/online-mode=false/' server.properties

# !wget -nc https://github.com/playit-cloud/playit-agent/releases/latest/download/playit-linux-amd64
# !chmod +x playit-linux-amd64

# !./playit-linux-amd64 --stdout --secret_path ./playit.toml & java -Xms6G -Xmx8G -XX:+UseG1GC -jar server.jar nogui
